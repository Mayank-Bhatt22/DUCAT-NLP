# %%
# !pip install nltk

# %% [markdown]
# ## One important assignment that I really want to give it is that try to find out the differences between NLTK and Spacy.

# %% [markdown]
# ## Let's say if I have a paragraph, how I can convert it into sentences, and then how I can convert into words all those things I'll be discussing and multiple ways of tokenization.

# %% [markdown]
# First of all I will try to define my own corpus.
# Corpus basically means paragraph.

# %%
corpus="""Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.
Please do follow the entire course! to become expert in NLP.
"""

# %%
corpus
# Out:
# "Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.\nPlease do follow the entire course! to become expert in NLP.\n"

# %%
print(corpus)
# Out:
# Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.
# Please do follow the entire course! to become expert in NLP.

# %%
import nltk
nltk.download('punkt')
nltk.download('punkt_tab')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# True

# %%
##  Tokenization
## Sentence-->paragraphs
from nltk.tokenize import sent_tokenize

# %%
sent_tokenize(corpus)
# Out:
# ["Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.",
#  'Please do follow the entire course!',
#  'to become expert in NLP.']

# %%
documents=sent_tokenize(corpus)

# %%
print(documents)
# Out:
# ["Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.", 'Please do follow the entire course!', 'to become expert in NLP.']

# %%
type(documents)
# Out:
# list

# %%
for sentence in documents:
    print(sentence)
# Out:
# Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.
# Please do follow the entire course!
# to become expert in NLP.

# %% [markdown]
# So next tokenization technique.
# What I am actually going to do is that.
# But next organization is that I can convert a paragraph. I can convert a paragraph into words.
# I can also convert a sentence into words.

# %%
## Tokenization
## Paragraph-->words
## sentence--->words
from nltk.tokenize import word_tokenize

# %% [markdown]
# And here if I directly give us my corpus here, you can see that each and every word has been divided.
# here you can see all the characters like comma full stop has been treated as a separate character altogether or separate words altogether.

# %%
word_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  'Upadhayay',
#  "'s",
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'follow',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
for sentence in documents:
    print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Abhishek', 'Upadhayay', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'follow', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  'Upadhayay',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'follow',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %% [markdown]
# And why do we do this?
#
# Because each and every word will have a different importance.
#
# And we really need to perform some pre-processing on top of it.

# %% [markdown]
# with respect to sentences, also, you know that how you can basically do just go over
#
# here and just write paste it over here for sentences in this.
#
# Now here you are printing the sentences right now.
#
# What you can basically do in that is that after you probably get this sentence, after you get the sentence altogether, you can just directly apply word tokenize, right?

# %%
for sentence in documents:
  print(sentence)
# Out:
# Hello Welcome,to Abhishek Upadhayay's NLP Tutorials.
# Please do follow the entire course!
# to become expert in NLP.

# %%
for sentence in documents:
  print(word_tokenize(sentence))
# Out:
# ['Hello', 'Welcome', ',', 'to', 'Abhishek', 'Upadhayay', "'s", 'NLP', 'Tutorials', '.']
# ['Please', 'do', 'follow', 'the', 'entire', 'course', '!']
# ['to', 'become', 'expert', 'in', 'NLP', '.']

# %%
from nltk.tokenize import wordpunct_tokenize

# %% [markdown]
# So I'm going to just write word Punkt tokenize.
#
# And in this word Punkt tokenize, what we are basically going to do is that if I try to apply this,
#
# if I try to initialize this word punk tokenize, and if I try to provide my corpus, let's say so here
#
# you just try to find out the difference.
#
# And one difference that is clearly seen is that this apostrophe s has also got splitted before it was
#
# not getting splitted, right.
#
# See, apostrophe s was a single word, but now you can see that it has been splitted.
#
# So that is the reason why we are using this.
#
# Punctuations.
#
# Uh, this punctuation is it is basically, uh, making sure that the punctuation will also be treated
#
# as a separate word.

# %%
wordpunct_tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  'Upadhayay',
#  "'",
#  's',
#  'NLP',
#  'Tutorials',
#  '.',
#  'Please',
#  'do',
#  'follow',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']

# %%
from nltk.tokenize import TreebankWordTokenizer

# %%
tokenizer=TreebankWordTokenizer()

# %%
tokenizer.tokenize(corpus)
# Out:
# ['Hello',
#  'Welcome',
#  ',',
#  'to',
#  'Abhishek',
#  'Upadhayay',
#  "'s",
#  'NLP',
#  'Tutorials.',
#  'Please',
#  'do',
#  'follow',
#  'the',
#  'entire',
#  'course',
#  '!',
#  'to',
#  'become',
#  'expert',
#  'in',
#  'NLP',
#  '.']
